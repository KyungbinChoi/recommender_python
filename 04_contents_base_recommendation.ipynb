# %% [markdown]
# ## Contents-based filtering
# * TF-IDF + cosine similarity

# %%
import os
from tqdm import tqdm
import pandas as pd
import numpy as np
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

import warnings
warnings.filterwarnings("ignore")

# %%
path = "./movielens/movielens100k/"
tags_df = pd.read_csv(os.path.join(path, 'tags.csv'), encoding='utf-8')
ratings_df = pd.read_csv(os.path.join(path, 'ratings.csv'), index_col = 'userId', encoding='utf-8')
movies_df = pd.read_csv(os.path.join(path, 'movies.csv'), index_col = 'movieId', encoding='utf-8')

# %%
total_count = len(movies_df.index)
total_genres = list(set([genre for sublist in list(map(lambda x: x.split('|'), movies_df['genres'])) for genre in sublist]))

# %%
total_genres
# Out:
# ['Romance',
#  'War',
#  'Crime',
#  'IMAX',
#  'Film-Noir',
#  'Musical',
#  'Horror',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Fantasy',
#  '(no genres listed)',
#  'Western',
#  'Documentary',
#  'Sci-Fi',
#  'Adventure',
#  'Mystery',
#  'Animation',
#  'Thriller',
#  'Children']

# %%
genre_count = dict.fromkeys(total_genres)

for each_genre_list in movies_df['genres']:
    for genre in each_genre_list.split('|'):
        if genre_count[genre] == None:
            genre_count[genre] = 1
        else:
            genre_count[genre] = genre_count[genre]+1

# %%
# create genre representations
genre_representation = pd.DataFrame(columns=sorted(total_genres), index=movies_df.index)
for index, each_row in tqdm(movies_df.iterrows()):
    dict_temp = {i: genre_count[i] for i in each_row['genres'].split('|')}
    row_to_add = pd.DataFrame(dict_temp, index=[index])
    genre_representation.update(row_to_add)

genre_representation
# Out:
# 9125it [00:07, 1213.11it/s]
#         (no genres listed)  Action Adventure Animation Children  Comedy Crime
# movieId
# 1                      NaN     NaN    1117.0     447.0    583.0  3315.0   NaN  \
# 2                      NaN     NaN    1117.0       NaN    583.0     NaN   NaN
# 3                      NaN     NaN       NaN       NaN      NaN  3315.0   NaN
# 4                      NaN     NaN       NaN       NaN      NaN  3315.0   NaN
# 5                      NaN     NaN       NaN       NaN      NaN  3315.0   NaN
# ...                    ...     ...       ...       ...      ...     ...   ...
# 162672                 NaN     NaN    1117.0       NaN      NaN     NaN   NaN
# 163056                 NaN  1545.0    1117.0       NaN      NaN     NaN   NaN
# 163949                 NaN     NaN       NaN       NaN      NaN     NaN   NaN
# 164977                 NaN     NaN       NaN       NaN      NaN  3315.0   NaN
# 164979                 NaN     NaN       NaN       NaN      NaN     NaN   NaN
#
#         Documentary   Drama Fantasy Film-Noir Horror IMAX Musical Mystery
# movieId
# 1               NaN     NaN   654.0       NaN    NaN  NaN     NaN     NaN  \
# 2               NaN     NaN   654.0       NaN    NaN  NaN     NaN     NaN
# 3               NaN     NaN     NaN       NaN    NaN  NaN     NaN     NaN
# 4               NaN  4365.0     NaN       NaN    NaN  NaN     NaN     NaN
# 5               NaN     NaN     NaN       NaN    NaN  NaN     NaN     NaN
# ...             ...     ...     ...       ...    ...  ...     ...     ...
# 162672          NaN  4365.0     NaN       NaN    NaN  NaN     NaN     NaN
# 163056          NaN     NaN   654.0       NaN    NaN  NaN     NaN     NaN
# 163949        495.0     NaN     NaN       NaN    NaN  NaN     NaN     NaN
# 164977          NaN     NaN     NaN       NaN    NaN  NaN     NaN     NaN
# 164979        495.0     NaN     NaN       NaN    NaN  NaN     NaN     NaN
#
#         Romance Sci-Fi Thriller  War Western
# movieId
# 1           NaN    NaN      NaN  NaN     NaN
# 2           NaN    NaN      NaN  NaN     NaN
# 3        1545.0    NaN      NaN  NaN     NaN
# 4        1545.0    NaN      NaN  NaN     NaN
# 5           NaN    NaN      NaN  NaN     NaN
# ...         ...    ...      ...  ...     ...
# 162672   1545.0    NaN      NaN  NaN     NaN
# 163056      NaN  792.0      NaN  NaN     NaN
# 163949      NaN    NaN      NaN  NaN     NaN
# 164977      NaN    NaN      NaN  NaN     NaN
# 164979      NaN    NaN      NaN  NaN     NaN
#
# [9125 rows x 20 columns]

# %%
# get unique tag
tag_column = list(map(lambda x: x.split(','), tags_df['tag']))
unique_tags = list(set(list(map(lambda x: x.strip(), list([tag for sublist in tag_column for tag in sublist])))))

print(unique_tags)
# Out:
# ['dull story', 'sword fight', 'plot holes', 'not by book', 'holes80s', 'gritty', 'dance', 'franchise', 'childish plot', 'alex pettyfer', 'complicated', 'hugh grant', 'aviation', 'sufficiently explodey to be good', 'dark humor', 'artificial intelligence', 'interesting concept - bad execution', 'guy movie', 'Nudity (Topless)', 'Brad Pitt', 'cooking', 'not too thrilled', 'horror', 'ocean', 'billy bob thorton', 'violent', 'christmas', 'toplist16', 'Takashi Miike', 'long', 'photography', 'unique look', 'vengeance', 'joseph fiennes', 'toplist13', 'Spanked', 'tarantino', 'genius', 'science fiction', 'jodi foster', 'must see', 'travel', 'cheerleading', 'toplist15', 'intelligent', 'guy ritchie', 'funny', 'sci-fi', 'devotion', 'Guillermo del Toro', 'I loved it! Seen it five times already!', 'getdvd', 'sexist', 'denzel washington', 'books', 'predictable', 'freedom', 'based on a true story', 'Studio Ghibli', 'sentimental', 'covers a lifespan', 'Zooey Deschanel', 'road trip', 'renegade art', 'dvd', 'Star Wars', 'family', 'Beautiful Woman', 'post-apocalyptic', 'lyrical', 'siblings', 'Intrigued', 'character development', 'Steve Buscemi', 'Funny', 'Ei muista', 'rich families', 'adapted from:book', 'Sandra Bullock', 'superhero', 'Leonardo DiCaprio', 'ensemble cast', 'directorial debut', 'kung fu', 'akira kurosawa', 'notable soundtrack', 'documentary', 'World War II', 'Oded Fehr', 'Rock', 'Billy Bob Thornton', 'Exellent first half', "didn't get it", 'British', 'starwars', 'toplist07', 'Fernando E. Solanas', 'baseball', 'holes60s', 'tcm', 'light', 'storyline', 'atmospheric', 'ending', 'breathtaking', 'shakespeare', 'football', 'stupidity', 'philosophy', 'martial arts', 'revenge', 'awkward', 'claire daines', 'hdtv', 'Nathan Fillion', 'romance', 'Drugs', 'diluted version of comic', 'witty!', 'girlie movie', 'comedt', 'ridiculous training sequence', 'hillarious', 'Mel Gibson', 'uganda', 'cool and great music', 'toplist11', 'femme-fatale', 'relativity', 'heartwarming', 'New York', 'adventure', 'sexy food', 'john cusack', 'vigilantism', 'Orlando Bloom', 'Benicio Del Toro', 'satirical', 'scary', 'magical realism', 'meaning of life', 'toplist10', 'mel gibson', 'nonlinear', 'villain nonexistent or not needed for good story', 'Romance', 'collin farrel', 'the best comic adaptation!', 'romantic comedy', 'joss whedon', 'politics', 'campy', 'Submission', 'jimmy stewart', 'Dave Foley', 'good but not accurate', 'survival horror', 'racism', 'aliens', 'pirates', 'Mindfuck', 'notable nudity', 'imaginative', 'Paris', 'surrealism', 'Jason Patric', 'cult film', 'musical', 'seen it before', 'jack nicholson', 'social criticism', 'memories', 'not only for kids', 'british', 'Phenomenal!', 'BDSM', 'b movie', 'Jeff Bridges', 'space', 'bollywood', 'R:strong sexual content', 'Udo Kier', 'graphic design', 'easily confused with other movie(s) (title)', 'keanu reeves', 'crude', 'beauty pageant', 'National Film Registry', 'intellectual', 'honest', 'overrated', 'school', 'american idiocy', 'off-beat comedy', 'Martin Scorsese', 'cute', 'meryl streep', 'time travel', 'nerds', 'strippers', 'Adam Sandler', 'powerpoint', 'who done it', 'Kevin Costner', 'holes70s', 'Kristen Stewart', 'Predictable', "sandra 'boring' bullock", 'ethan hawke', 'feel-good', 'Teen movie', 'liked the other two better', 'story', 'math', 'prison escape', 'Marx Brothers', 'holes90s', 'cursing', 'beautifully filmed', 'boring', 'jedi', 'Viggo Mortensen', 'Irene Jacob', 'alternate reality', 'bad acting', 'Roman Polanski', 'self discovery', 'original plot', 'stereotypes', 'romantic', 'super-hero', 'Psychological Thriller', 'Domination', 'will farell', 'standard romantic comedy', 'Gore!!!', 'teenagers', 'toplist14', 'physics', 'Long', 'No progress', 'characters', 'cult classic', 'strong female presence', 'sad', 'Tom Hanks', 'visceral', 'Rosanna Arquette', 'fairy tale', 'Firefly', 'Morgan Freeman', 'CHRISTIAN', 'tobey maguire', 'violence', 'moody', 'biblical', 'psychological thriller', 'musical parodies', 'philosophi ...

# %%
# Compute IDF for tag
total_movie_count = len(set(tags_df['movieId']))
# key: tag, value: number of movies with such tag
tag_count_dict = dict.fromkeys(unique_tags)

for each_movie_tag_list in tags_df['tag']:
    for tag in each_movie_tag_list.split(","):
        if tag_count_dict[tag.strip()] == None:
            tag_count_dict[tag.strip()] = 1
        else:
            tag_count_dict[tag.strip()] += 1

tag_idf = dict()
for each_tag in tag_count_dict:
    tag_idf[each_tag] = np.log10(total_movie_count / tag_count_dict[each_tag])

tag_idf
# Out:
# {'dull story': 2.8382192219076257,
#  'sword fight': 2.8382192219076257,
#  'plot holes': 2.8382192219076257,
#  'not by book': 2.8382192219076257,
#  'holes80s': 1.6920911862293877,
#  'gritty': 2.8382192219076257,
#  'dance': 2.5371892262436444,
#  'franchise': 2.8382192219076257,
#  'childish plot': 2.8382192219076257,
#  'alex pettyfer': 2.8382192219076257,
#  'complicated': 2.8382192219076257,
#  'hugh grant': 2.8382192219076257,
#  'aviation': 2.8382192219076257,
#  'sufficiently explodey to be good': 2.8382192219076257,
#  'dark humor': 2.5371892262436444,
#  'artificial intelligence': 2.8382192219076257,
#  'Neil Gaiman': 2.8382192219076257,
#  'Disney': 2.3610979671879635,
#  'Emilio Estevez': 2.8382192219076257,
#  'but still a fun movie.': 2.8382192219076257,
#  'Vin Diesel': 2.8382192219076257,
#  'magic': 2.8382192219076257,
#  'pregnancy': 2.8382192219076257,
#  'rock and roll': 2.8382192219076257,
#  'based on a book': 2.8382192219076257,
#  'Nicolas Cage': 2.8382192219076257,
#  'on the run': 2.8382192219076257,
#  'hallucinatory': 2.8382192219076257,
#  'war': 2.5371892262436444,
#  'afi': 1.883976712468301,
#  'Bill Murray': 2.3610979671879635,
#  'forgettable': 2.8382192219076257,
#  'privacy': 2.8382192219076257,
#  'controversial': 2.8382192219076257,
#  'Streep strong & funny': 2.8382192219076257,
#  'organized crime': 2.3610979671879635,
#  'mad scientist': 2.5371892262436444,
#  'vampires': 2.8382192219076257,
#  'psychology': 1.9351292349156823,
#  'amazing storytelling': 2.8382192219076257,
#  'touching': 2.8382192219076257,
#  'friends': 2.8382192219076257,
#  'stupid': 2.5371892262436444,
#  'porn': 2.8382192219076257,
#  'Steve Martin': 2.5371892262436444}

# %%
# Create movie representations
tag_representation = pd.DataFrame(columns=sorted(unique_tags), index=list(set(tags_df['movieId'])))
for name, group in tqdm(tags_df.groupby(by='movieId')):
    temp_list = list(map(lambda x: x.split(','), list(group['tag'])))
    temp_tag_list = list(set(list(map(lambda x: x.strip(), list([tag for sublist in temp_list for tag in sublist])))))

    dict_temp = {i: tag_idf[i.strip()] for i in temp_tag_list}
    row_to_add = pd.DataFrame(dict_temp, index=[group['movieId'].values[0]])
    tag_representation.update(row_to_add)

tag_representation = tag_representation.sort_index()
tag_representation
# Out:
# 100%|██████████| 689/689 [00:00<00:00, 2482.49it/s]
#        1940's feel 80's classic Abigail Breslin Adam Sandler Aging
# 1              NaN          NaN             NaN          NaN   NaN  \
# 5              NaN          NaN             NaN          NaN   NaN
# 47             NaN          NaN             NaN          NaN   NaN
# 50             NaN          NaN             NaN          NaN   NaN
# 104            NaN          NaN             NaN          NaN   NaN
# ...            ...          ...             ...          ...   ...
# 161582         NaN          NaN             NaN          NaN   NaN
# 163056         NaN          NaN             NaN          NaN   NaN
# 163949         NaN          NaN             NaN          NaN   NaN
# 164977         NaN          NaN             NaN          NaN   NaN
# 164979         NaN          NaN             NaN          NaN   NaN
#
#        Aging Disorder Alex van Warmerdam Alfred Hitchcock Amanda Peet Ang Lee
# 1                 NaN                NaN              NaN         NaN     NaN  \
# 5                 NaN                NaN              NaN         NaN     NaN
# 47                NaN                NaN              NaN         NaN     NaN
# 50                NaN                NaN              NaN         NaN     NaN
# 104               NaN                NaN              NaN         NaN     NaN
# ...               ...                ...              ...         ...     ...
# 161582            NaN                NaN              NaN         NaN     NaN
# 163056            NaN                NaN              NaN         NaN     NaN
# 163949            NaN                NaN              NaN         NaN     NaN
# 164977            NaN                NaN              NaN         NaN     NaN
# 164979            NaN                NaN              NaN         NaN     NaN
#
#         ...  war weird well done whimsical who done it will farell witty
# 1       ...  NaN   NaN       NaN       NaN         NaN         NaN   NaN  \
# 5       ...  NaN   NaN       NaN       NaN         NaN         NaN   NaN
# 47      ...  NaN   NaN       NaN       NaN         NaN         NaN   NaN
# 50      ...  NaN   NaN       NaN       NaN         NaN         NaN   NaN
# 104     ...  NaN   NaN       NaN       NaN         NaN         NaN   NaN
# ...     ...  ...   ...       ...       ...         ...         ...   ...
# 161582  ...  NaN   NaN       NaN       NaN         NaN         NaN   NaN
# 163056  ...  NaN   NaN       NaN       NaN         NaN         NaN   NaN
# 163949  ...  NaN   NaN       NaN       NaN         NaN         NaN   NaN
# 164977  ...  NaN   NaN       NaN       NaN         NaN         NaN   NaN
# 164979  ...  NaN   NaN       NaN       NaN         NaN         NaN   NaN
#
#        witty! wrongful imprisonment zombies
# 1         NaN                   NaN     NaN
# 5         NaN                   NaN     NaN
# 47        NaN                   NaN     NaN
# 50        NaN                   NaN     NaN
# 104       NaN                   NaN     NaN
# ...       ...                   ...     ...
# 161582    NaN                   NaN     NaN
# 163056    NaN                   NaN     NaN
# 163949    NaN                   NaN     NaN
# 164977    NaN                   NaN     NaN
# 164979    NaN                   NaN     NaN
#
# [689 rows x 586 columns]

# %%
movie_representation = pd.concat([genre_representation, tag_representation], axis=1).fillna(0)
print(movie_representation.shape)
print(movie_representation.describe())
# Out:
# (9125, 606)
#        (no genres listed)       Action    Adventure    Animation     Children
# count         9125.000000  9125.000000  9125.000000  9125.000000  9125.000000  \
# mean             0.035507   261.591781   136.733041    21.896877    37.248110
# std              0.798707   579.453051   366.127809    96.485496   142.584902
# min              0.000000     0.000000     0.000000     0.000000     0.000000
# 25%              0.000000     0.000000     0.000000     0.000000     0.000000
# 50%              0.000000     0.000000     0.000000     0.000000     0.000000
# 75%              0.000000     0.000000     0.000000     0.000000     0.000000
# max             18.000000  1545.000000  1117.000000   447.000000   583.000000
#
#             Comedy        Crime  Documentary        Drama      Fantasy  ...
# count  9125.000000  9125.000000  9125.000000  9125.000000  9125.000000  ...  \
# mean   1204.298630   132.602740    26.852055  2088.024658    46.872986  ...
# std    1594.425716   358.180941   112.125430  2180.573719   168.703809  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 75%    3315.000000     0.000000     0.000000  4365.000000     0.000000  ...
# max    3315.000000  1100.000000   495.000000  4365.000000   654.000000  ...
#
#                war        weird    well done    whimsical  who done it
# count  9125.000000  9125.000000  9125.000000  9125.000000  9125.000000  \
# mean      0.000556     0.000556     0.000311     0.000556     0.000311
# std       0.037560     0.037560     0.029712     0.037560     0.029712
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     0.000000     0.000000     0.000000
# max       2.537189     2.537189     2.838219     2.537189     2.838219
#
#        will farell        witty       witty!  wrongful imprisonment
# count  9125.000000  9125.000000  9125.000000            9125.000000  \
# mean      0.000311     0.000311     0.000311               0.000311
# std       0.029712     0.029712     0.029712               0.029712
# min       0.000000     0.000000     0.000000               0.000000
# 25%       0.000000     0.000000     0.000000               0.000000
# 50%       0.000000     0.000000     0.000000               0.000000
# 75%       0.000000     0.000000     0.000000               0.000000
# max       2.838219     2.838219     2.838219               2.838219
#
#            zombies
# count  9125.000000
# mean      0.000556
# std       0.037560
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       2.537189
#
# [8 rows x 606 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity

def cos_sim_matrix(a, b):
    cos_sim = cosine_similarity(a, b)
    result_df = pd.DataFrame(data=cos_sim, index=[a.index])

    return result_df

# %%
cs_df = cos_sim_matrix(movie_representation, movie_representation)
cs_df.head()
# Out:
#        0         1         2         3         4     5         6         7
# 1  1.000000  0.390671  0.826878  0.531054  0.912274   0.0  0.826878  0.346744  \
# 2  0.390671  1.000000  0.000000  0.000000  0.000000   0.0  0.000000  0.887561
# 3  0.826878  0.000000  1.000000  0.642240  0.906392   0.0  1.000000  0.000000
# 4  0.531054  0.000000  0.642240  1.000000  0.582121   0.0  0.642240  0.000000
# 5  0.912274  0.000000  0.906392  0.582121  1.000000   0.0  0.906392  0.000000
#
#    8         9     ...      9115      9116      9117      9118      9119
# 1   0.0  0.133408  ...  0.000000  0.153079  0.000000  0.000000  0.000000  \
# 2   0.0  0.341485  ...  0.000000  0.391837  0.000000  0.000000  0.000000
# 3   0.0  0.000000  ...  0.000000  0.000000  0.000000  0.000000  0.281476
# 4   0.0  0.000000  ...  0.700517  0.000000  0.766504  0.766504  0.180775
# 5   0.0  0.000000  ...  0.000000  0.000000  0.000000  0.000000  0.000000
#
#        9120      9121  9122      9123  9124
# 1  0.072086  0.212907   0.0  0.912274   0.0
# 2  0.184518  0.544977   0.0  0.000000   0.0
# 3  0.137023  0.000000   0.0  0.906393   0.0
# 4  0.790428  0.000000   0.0  0.582121   0.0
# 5  0.000000  0.000000   0.0  1.000000   0.0
#
# [5 rows x 9125 columns]

# %%
print(movies_df.loc[1])
print(movies_df.loc[46972])
print(movies_df.loc[2043])
print(movies_df.loc[2399])
# Out:
# title                                Toy Story (1995)
# genres    Adventure|Animation|Children|Comedy|Fantasy
# Name: 1, dtype: object
# title     Night at the Museum (2006)
# genres    Action|Comedy|Fantasy|IMAX
# Name: 46972, dtype: object
# title     Darby O'Gill and the Little People (1959)
# genres                   Adventure|Children|Fantasy
# Name: 2043, dtype: object
# title     Santa Claus: The Movie (1985)
# genres       Adventure|Children|Fantasy
# Name: 2399, dtype: object

# %%
# split train and test set
train_df, test_df = train_test_split(ratings_df.reset_index(), test_size=.2, random_state=123)
print(train_df.shape)
print(test_df.shape)
# Out:
# (80003, 4)
# (20001, 4)

# %%
test_userids = list(set(test_df.userId.values))

# %%
result_df = pd.DataFrame()

for user_id in tqdm(test_userids):
    user_record_df = train_df.loc[train_df.userId == int(user_id), :]
    
    user_sim_df = cs_df.loc[user_record_df['movieId']]  
    user_rating_df = user_record_df[['rating']]  
    sim_sum = np.sum(user_sim_df.T.to_numpy(), -1) 
    # print("user_id=", user_id, user_record_df.shape, user_sim_df.T.shape, user_rating_df.shape, sim_sum.shape)

    prediction = np.matmul(user_sim_df.T.to_numpy(), user_rating_df.to_numpy()).flatten() / (sim_sum+1) 

    prediction_df = pd.DataFrame(prediction, index=cs_df.index).reset_index()
    prediction_df.columns = ['movieId', 'pred_rating']    
    prediction_df = prediction_df[['movieId', 'pred_rating']][prediction_df.movieId.isin(test_df[test_df.userId == user_id]['movieId'].values)]

    temp_df = prediction_df.merge(test_df[test_df.userId == user_id], on='movieId')
    result_df = pd.concat([result_df, temp_df], axis=0)
# Out:
# 100%|██████████| 671/671 [00:03<00:00, 202.18it/s]

# %%
result_df.head()
# Out:
#    movieId  pred_rating  userId  rating   timestamp
# 0     1061     1.870937       1     3.0  1260759182
# 1     1339     1.675645       1     3.5  1260759125
# 2     2105     1.802382       1     4.0  1260759139
# 0       47     2.914872       2     4.0   835355552
# 1       50     2.968990       2     4.0   835355586

# %%
mse = mean_squared_error(y_true=result_df['rating'].values, y_pred=result_df['pred_rating'].values)
rmse = np.sqrt(mse)

print(mse, rmse)
# Out:
# 0.9776362023305245 0.9887548747442535
